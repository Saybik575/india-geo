# %%
import pandas

# %%
df_HP = pandas.read_excel('dataset/Rdir_2011_02_HIMACHAL_PRADESH.xls')

# %%
df_HP.columns
# Out:
# Index(['MDDS STC', 'STATE NAME', 'MDDS DTC', 'DISTRICT NAME', 'MDDS Sub_DT',
#        'SUB-DISTRICT NAME', 'MDDS PLCN', 'Area Name'],
#       dtype='object')

# %%
df_HP.head()
# Out:
#    MDDS STC        STATE NAME  MDDS DTC     DISTRICT NAME  MDDS Sub_DT  \
# 0         2  HIMACHAL PRADESH         0  HIMACHAL PRADESH            0
# 1         2  HIMACHAL PRADESH        23            Chamba            0
# 2         2  HIMACHAL PRADESH        23            Chamba           83
# 3         2  HIMACHAL PRADESH        23            Chamba           83
# 4         2  HIMACHAL PRADESH        23            Chamba           83
#
#   SUB-DISTRICT NAME  MDDS PLCN         Area Name
# 0  HIMACHAL PRADESH          0  HIMACHAL PRADESH
# 1            Chamba          0            Chamba
# 2             Pangi          0             Pangi
# 3             Pangi       6673      R.F.Luj  (6)
# 4             Pangi       6674          Luj  (7)

# %%
df_states = df_HP[['MDDS STC', 'STATE NAME']]

# %%
df_states = df_states.drop_duplicates()

# %%
df_states = df_states.rename(columns={
    'MDDS STC': 'state_code',
    'STATE NAME': 'state_name'
})

# %%
df_states
# Out:
#    state_code        state_name
# 0           2  HIMACHAL PRADESH

# %%
df_PB = pandas.read_excel('dataset/Rdir_2011_03_PUNJAB.xls')
df_PB.head()
# Out:
#    MDDS STC STATE NAME  MDDS DTC DISTRICT NAME  MDDS Sub_DT SUB-DISTRICT NAME  \
# 0         3     PUNJAB         0        PUNJAB            0            PUNJAB
# 1         3     PUNJAB        35     Gurdaspur            0         Gurdaspur
# 2         3     PUNJAB        35     Gurdaspur          200        Dhar Kalan
# 3         3     PUNJAB        35     Gurdaspur          200        Dhar Kalan
# 4         3     PUNJAB        35     Gurdaspur          200        Dhar Kalan
#
#    MDDS PLCN            Area Name
# 0          0               PUNJAB
# 1          0            Gurdaspur
# 2          0           Dhar Kalan
# 3      27374        Darbahn (406)
# 4      27375  Darkua Bangla (405)

# %%
df_HP = pandas.read_excel('dataset/Rdir_2011_02_HIMACHAL_PRADESH.xls')
df_PB = pandas.read_excel('dataset/Rdir_2011_03_PUNJAB.xls')
df_HR = pandas.read_excel('dataset/Rdir_2011_06_HARYANA.xls')
df_RJ = pandas.read_excel('dataset/Rdir_2011_08_RAJASTHAN.xls')
df_UP = pandas.read_excel('dataset/Rdir_2011_09_UTTAR_PRADESH.ods')
df_BR = pandas.read_excel('dataset/Rdir_2011_10_BIHAR.xls')
df_SK = pandas.read_excel('dataset/Rdir_2011_11_SIKKIM.xls')
df_AR = pandas.read_excel('dataset/Rdir_2011_12_ARUNACHAL_PRADESH.xls')
df_NL = pandas.read_excel('dataset/Rdir_2011_13_NAGALAND.xls')
df_MZ = pandas.read_excel('dataset/Rdir_2011_15_MIZORAM.xls')
df_TR = pandas.read_excel('dataset/Rdir_2011_16_TRIPURA.xls')
df_ML = pandas.read_excel('dataset/Rdir_2011_17_MEGHALAYA.xls')
df_AS = pandas.read_excel('dataset/Rdir_2011_18_ASSAM.xls')
df_WB = pandas.read_excel('dataset/Rdir_2011_19_WEST_BENGAL.xls')
df_JH = pandas.read_excel('dataset/Rdir_2011_20_JHARKHAND.xls')
df_OD = pandas.read_excel('dataset/Rdir_2011_21_ODISHA.xls')
df_CG = pandas.read_excel('dataset/Rdir_2011_22_CHHATTISGARH.xls')
df_MP = pandas.read_excel('dataset/Rdir_2011_23_MADHYA_PRADESH.xls', sheet_name='Village Directory')
df_GJ = pandas.read_excel('dataset/Rdir_2011_24_GUJARAT.xls')
df_DD = pandas.read_excel('dataset/Rdir_2011_25_DAMAN_and_DIU.xls')
df_DNH = pandas.read_excel('dataset/Rdir_2011_26_DADRA_and_NAGAR_HAVELI.xls')
df_MH = pandas.read_excel('dataset/Rdir_2011_27_MAHARASHTRA.xls')
df_AP = pandas.read_excel('dataset/Rdir_2011_28_ANDHRA_PRADESH.xls')
df_KA = pandas.read_excel('dataset/Rdir_2011_29_KARNATAKA.xls')
df_GA = pandas.read_excel('dataset/Rdir_2011_30_GOA.xls')
df_LD = pandas.read_excel('dataset/Rdir_2011_31_LAKSHADWEEP.xls')
df_KL = pandas.read_excel('dataset/Rdir_2011_32_KERALA.xls')
df_TN = pandas.read_excel('dataset/Rdir_2011_33_TAMIL_NADU.xls')
df_PY = pandas.read_excel('dataset/Rdir_2011_34_PUDUCHERRY.xls')
df_AN = pandas.read_excel('dataset/Rdir_2011_35_ANDAMAN_and_NICOBAR_ISLANDS.xls')

# %%
df_states = pandas.concat([
    df_HP[['MDDS STC', 'STATE NAME']],
    df_PB[['MDDS STC', 'STATE NAME']],
    df_HR[['MDDS STC', 'STATE NAME']],
    df_RJ[['MDDS STC', 'STATE NAME']],
    df_UP[['MDDS STC', 'STATE NAME']],
    df_BR[['MDDS STC', 'STATE NAME']],
    df_SK[['MDDS STC', 'STATE NAME']],
    df_AR[['MDDS STC', 'STATE NAME']],
    df_NL[['MDDS STC', 'STATE NAME']],
    df_MZ[['MDDS STC', 'STATE NAME']],
    df_TR[['MDDS STC', 'STATE NAME']],
    df_ML[['MDDS STC', 'STATE NAME']],
    df_AS[['MDDS STC', 'STATE NAME']],
    df_WB[['MDDS STC', 'STATE NAME']],
    df_JH[['MDDS STC', 'STATE NAME']],
    df_OD[['MDDS STC', 'STATE NAME']],
    df_CG[['MDDS STC', 'STATE NAME']],
    df_MP[['MDDS STC', 'STATE NAME']],
    df_GJ[['MDDS STC', 'STATE NAME']],
    df_DD[['MDDS STC', 'STATE NAME']],
    df_DNH[['MDDS STC', 'STATE NAME']],
    df_MH[['MDDS STC', 'STATE NAME']],
    df_AP[['MDDS STC', 'STATE NAME']],
    df_KA[['MDDS STC', 'STATE NAME']],
    df_GA[['MDDS STC', 'STATE NAME']],
    df_LD[['MDDS STC', 'STATE NAME']],
    df_KL[['MDDS STC', 'STATE NAME']],
    df_TN[['MDDS STC', 'STATE NAME']],
    df_PY[['MDDS STC', 'STATE NAME']],
    df_AN[['MDDS STC', 'STATE NAME']]
])

df_states = (
    df_states
    .drop_duplicates()
    .rename(columns={'MDDS STC': 'state_code', 'STATE NAME': 'state_name'})
    .sort_values('state_code')
    .reset_index(drop=True)
 )

df_states
# Out:
#     state_code                 state_name
# 0            2           HIMACHAL PRADESH
# 1            3                     PUNJAB
# 2            6                    HARYANA
# 3            8                  RAJASTHAN
# 4            9              UTTAR PRADESH
# 5           10                      BIHAR
# 6           11                     SIKKIM
# 7           12          ARUNACHAL PRADESH
# 8           13                   NAGALAND
# 9           15                    MIZORAM
# 10          16                    TRIPURA
# 11          17                  MEGHALAYA
# 12          18                      ASSAM
# 13          19                WEST BENGAL
# 14          20                  JHARKHAND
# 15          21                     ODISHA
# 16          22               CHHATTISGARH
# 17          23             MADHYA PRADESH
# 18          24                    GUJARAT
# 19          25                DAMAN & DIU
# 20          26       DADRA & NAGAR HAVELI
# ...

# %%
df_states.isna().sum()
# Out:
# state_code    0
# state_name    0
# dtype: int64

# %%
df_districts = pandas.concat([
    df_HP[['MDDS DTC', 'DISTRICT NAME', 'MDDS STC']],
    df_PB[['MDDS DTC', 'DISTRICT NAME', 'MDDS STC']],
    df_HR[['MDDS DTC', 'DISTRICT NAME', 'MDDS STC']],
    df_RJ[['MDDS DTC', 'DISTRICT NAME', 'MDDS STC']],
    df_UP[['MDDS DTC', 'DISTRICT NAME', 'MDDS STC']],
    df_BR[['MDDS DTC', 'DISTRICT NAME', 'MDDS STC']],
    df_SK[['MDDS DTC', 'DISTRICT NAME', 'MDDS STC']],
    df_AR[['MDDS DTC', 'DISTRICT NAME', 'MDDS STC']],
    df_NL[['MDDS DTC', 'DISTRICT NAME', 'MDDS STC']],
    df_MZ[['MDDS DTC', 'DISTRICT NAME', 'MDDS STC']],
    df_TR[['MDDS DTC', 'DISTRICT NAME', 'MDDS STC']],
    df_ML[['MDDS DTC', 'DISTRICT NAME', 'MDDS STC']],
    df_AS[['MDDS DTC', 'DISTRICT NAME', 'MDDS STC']],
    df_WB[['MDDS DTC', 'DISTRICT NAME', 'MDDS STC']],
    df_JH[['MDDS DTC', 'DISTRICT NAME', 'MDDS STC']],
    df_OD[['MDDS DTC', 'DISTRICT NAME', 'MDDS STC']],
    df_CG[['MDDS DTC', 'DISTRICT NAME', 'MDDS STC']],
    df_MP[['MDDS DTC', 'DISTRICT NAME', 'MDDS STC']],
    df_GJ[['MDDS DTC', 'DISTRICT NAME', 'MDDS STC']],
    df_DD[['MDDS DTC', 'DISTRICT NAME', 'MDDS STC']],
    df_DNH[['MDDS DTC', 'DISTRICT NAME', 'MDDS STC']],
    df_MH[['MDDS DTC', 'DISTRICT NAME', 'MDDS STC']],
    df_AP[['MDDS DTC', 'DISTRICT NAME', 'MDDS STC']],
    df_KA[['MDDS DTC', 'DISTRICT NAME', 'MDDS STC']],
    df_GA[['MDDS DTC', 'DISTRICT NAME', 'MDDS STC']],
    df_LD[['MDDS DTC', 'DISTRICT NAME', 'MDDS STC']],
    df_KL[['MDDS DTC', 'DISTRICT NAME', 'MDDS STC']],
    df_TN[['MDDS DTC', 'DISTRICT NAME', 'MDDS STC']],
    df_PY[['MDDS DTC', 'DISTRICT NAME', 'MDDS STC']],
    df_AN[['MDDS DTC', 'DISTRICT NAME', 'MDDS STC']]
])

df_districts = (
    df_districts
    .drop_duplicates()
    .rename(columns={'MDDS DTC': 'district_code', 'DISTRICT NAME': 'district_name', 'MDDS STC': 'state_code'})
)

# Some files include a state-level summary row in district columns (district_code = 0).
df_districts['district_code'] = pandas.to_numeric(df_districts['district_code'], errors='coerce')
df_districts = df_districts[df_districts['district_code'].ne(0)]

df_districts = (
    df_districts
    .sort_values(['state_code', 'district_code'])
    .reset_index(drop=True)
 )

df_districts
# Out:
#      district_code            district_name  state_code
# 0               23                   Chamba           2
# 1               24                   Kangra           2
# 2               25            Lahul & Spiti           2
# 3               26                    Kullu           2
# 4               27                    Mandi           2
# ..             ...                      ...         ...
# 581            636                     Mahe          34
# 582            637                 Karaikal          34
# 583            638                 Nicobars          35
# 584            639  North  & Middle Andaman          35
# 585            640            South Andaman          35
#
# [586 rows x 3 columns]

# %%
df_districts.isna().sum()
# Out:
# district_code    0
# district_name    0
# state_code       0
# dtype: int64

# %%
df_subdisticts = pandas.concat([
    df_HP[['MDDS Sub_DT', 'SUB-DISTRICT NAME', 'MDDS DTC']],
    df_PB[['MDDS Sub_DT', 'SUB-DISTRICT NAME', 'MDDS DTC']],
    df_HR[['MDDS Sub_DT', 'SUB-DISTRICT NAME', 'MDDS DTC']],
    df_RJ[['MDDS Sub_DT', 'SUB-DISTRICT NAME', 'MDDS DTC']],
    df_UP[['MDDS Sub_DT', 'SUB-DISTRICT NAME', 'MDDS DTC']],
    df_BR[['MDDS Sub_DT', 'SUB-DISTRICT NAME', 'MDDS DTC']],
    df_SK[['MDDS Sub_DT', 'SUB-DISTRICT NAME', 'MDDS DTC']],
    df_AR[['MDDS Sub_DT', 'SUB-DISTRICT NAME', 'MDDS DTC']],
    df_NL[['MDDS Sub_DT', 'SUB-DISTRICT NAME', 'MDDS DTC']],
    df_MZ[['MDDS Sub_DT', 'SUB-DISTRICT NAME', 'MDDS DTC']],
    df_TR[['MDDS Sub_DT', 'SUB-DISTRICT NAME', 'MDDS DTC']],
    df_ML[['MDDS Sub_DT', 'SUB-DISTRICT NAME', 'MDDS DTC']],
    df_AS[['MDDS Sub_DT', 'SUB-DISTRICT NAME', 'MDDS DTC']],
    df_WB[['MDDS Sub_DT', 'SUB-DISTRICT NAME', 'MDDS DTC']],
    df_JH[['MDDS Sub_DT', 'SUB-DISTRICT NAME', 'MDDS DTC']],
    df_OD[['MDDS Sub_DT', 'SUB-DISTRICT NAME', 'MDDS DTC']],
    df_CG[['MDDS Sub_DT', 'SUB-DISTRICT NAME', 'MDDS DTC']],
    df_MP[['MDDS Sub_DT', 'SUB-DISTRICT NAME', 'MDDS DTC']],
    df_GJ[['MDDS Sub_DT', 'SUB-DISTRICT NAME', 'MDDS DTC']],
    df_DD[['MDDS Sub_DT', 'SUB-DISTRICT NAME', 'MDDS DTC']],
    df_DNH[['MDDS Sub_DT', 'SUB-DISTRICT NAME', 'MDDS DTC']],
    df_MH[['MDDS Sub_DT', 'SUB-DISTRICT NAME', 'MDDS DTC']],
    df_AP[['MDDS Sub_DT', 'SUB-DISTRICT NAME', 'MDDS DTC']],
    df_KA[['MDDS Sub_DT', 'SUB-DISTRICT NAME', 'MDDS DTC']],
    df_GA[['MDDS Sub_DT', 'SUB-DISTRICT NAME', 'MDDS DTC']],
    df_LD[['MDDS Sub_DT', 'SUB-DISTRICT NAME', 'MDDS DTC']],
    df_KL[['MDDS Sub_DT', 'SUB-DISTRICT NAME', 'MDDS DTC']],
    df_TN[['MDDS Sub_DT', 'SUB-DISTRICT NAME', 'MDDS DTC']],
    df_PY[['MDDS Sub_DT', 'SUB-DISTRICT NAME', 'MDDS DTC']],
    df_AN[['MDDS Sub_DT', 'SUB-DISTRICT NAME', 'MDDS DTC']]
])

df_subdisticts = (
    df_subdisticts
    .drop_duplicates()
    .rename(columns={'MDDS Sub_DT': 'subdistrict_code', 'SUB-DISTRICT NAME': 'subdistrict_name', 'MDDS DTC': 'district_code'})
)

df_subdisticts['subdistrict_code'] = pandas.to_numeric(df_subdisticts['subdistrict_code'], errors='coerce')
df_subdisticts = df_subdisticts[df_subdisticts['subdistrict_code'].notna()]
df_subdisticts = df_subdisticts[df_subdisticts['subdistrict_code'].ne(0)]
df_subdisticts['subdistrict_code'] = df_subdisticts['subdistrict_code'].astype('Int64')

df_subdisticts = (
    df_subdisticts
    .sort_values(['district_code', 'subdistrict_code'])
    .reset_index(drop=True)
)

df_subdisticts
# Out:
#       subdistrict_code subdistrict_name  district_code
# 0                   83            Pangi             23
# 1                   84          Chaurah             23
# 2                   85           Saluni             23
# 3                   86           Bhalai             23
# 4                   87        Dalhousie             23
# ...                ...              ...            ...
# 5759              5920       Mayabunder            639
# 5760              5921           Rangat            639
# 5761              5922       Ferrargunj            640
# 5762              5923       Port Blair            640
# 5763              5924   Little Andaman            640
#
# [5764 rows x 3 columns]

# %%
df_subdisticts.isna().sum()
df_subdisticts.duplicated().sum()
# Out:
# 0

# %%
df_villages = pandas.concat([
    df_HP[['MDDS PLCN', 'Area Name', 'MDDS Sub_DT', 'MDDS DTC']],
    df_PB[['MDDS PLCN', 'Area Name', 'MDDS Sub_DT', 'MDDS DTC']],
    df_HR[['MDDS PLCN', 'Area Name', 'MDDS Sub_DT', 'MDDS DTC']],
    df_RJ[['MDDS PLCN', 'Area Name', 'MDDS Sub_DT', 'MDDS DTC']],
    df_UP[['MDDS PLCN', 'Area Name', 'MDDS Sub_DT', 'MDDS DTC']],
    df_BR[['MDDS PLCN', 'Area Name', 'MDDS Sub_DT', 'MDDS DTC']],
    df_SK[['MDDS PLCN', 'Area Name', 'MDDS Sub_DT', 'MDDS DTC']],
    df_AR[['MDDS PLCN', 'Area Name', 'MDDS Sub_DT', 'MDDS DTC']],
    df_NL[['MDDS PLCN', 'Area Name', 'MDDS Sub_DT', 'MDDS DTC']],
    df_MZ[['MDDS PLCN', 'Area Name', 'MDDS Sub_DT', 'MDDS DTC']],
    df_TR[['MDDS PLCN', 'Area Name', 'MDDS Sub_DT', 'MDDS DTC']],
    df_ML[['MDDS PLCN', 'Area Name', 'MDDS Sub_DT', 'MDDS DTC']],
    df_AS[['MDDS PLCN', 'Area Name', 'MDDS Sub_DT', 'MDDS DTC']],
    df_WB[['MDDS PLCN', 'Area Name', 'MDDS Sub_DT', 'MDDS DTC']],
    df_JH[['MDDS PLCN', 'Area Name', 'MDDS Sub_DT', 'MDDS DTC']],
    df_OD[['MDDS PLCN', 'Area Name', 'MDDS Sub_DT', 'MDDS DTC']],
    df_CG[['MDDS PLCN', 'Area Name', 'MDDS Sub_DT', 'MDDS DTC']],
    df_MP[['MDDS PLCN', 'Area Name', 'MDDS Sub_DT', 'MDDS DTC']],
    df_GJ[['MDDS PLCN', 'Area Name', 'MDDS Sub_DT', 'MDDS DTC']],
    df_DD[['MDDS PLCN', 'Area Name', 'MDDS Sub_DT', 'MDDS DTC']],
    df_DNH[['MDDS PLCN', 'Area Name', 'MDDS Sub_DT', 'MDDS DTC']],
    df_MH[['MDDS PLCN', 'Area Name', 'MDDS Sub_DT', 'MDDS DTC']],
    df_AP[['MDDS PLCN', 'Area Name', 'MDDS Sub_DT', 'MDDS DTC']],
    df_KA[['MDDS PLCN', 'Area Name', 'MDDS Sub_DT', 'MDDS DTC']],
    df_GA[['MDDS PLCN', 'Area Name', 'MDDS Sub_DT', 'MDDS DTC']],
    df_LD[['MDDS PLCN', 'Area Name', 'MDDS Sub_DT', 'MDDS DTC']],
    df_KL[['MDDS PLCN', 'Area Name', 'MDDS Sub_DT', 'MDDS DTC']],
    df_TN[['MDDS PLCN', 'Area Name', 'MDDS Sub_DT', 'MDDS DTC']],
    df_PY[['MDDS PLCN', 'Area Name', 'MDDS Sub_DT', 'MDDS DTC']],
    df_AN[['MDDS PLCN', 'Area Name', 'MDDS Sub_DT', 'MDDS DTC']]
])

df_villages = (
    df_villages
    .drop_duplicates()
    .rename(columns={'MDDS PLCN': 'village_code', 'Area Name': 'village_name', 'MDDS Sub_DT': 'subdistrict_code', 'MDDS DTC': 'district_code'})
)

df_villages['village_code'] = pandas.to_numeric(df_villages['village_code'], errors='coerce')
df_villages = df_villages[df_villages['village_code'].notna()]
df_villages = df_villages[df_villages['village_code'].ne(0)]

df_villages = (
    df_villages
    .sort_values(['district_code', 'subdistrict_code', 'village_code'])
    .reset_index(drop=True)
)

df_villages
# Out:
#         village_code                         village_name  subdistrict_code  \
# 0               6673                         R.F.Luj  (6)              83.0
# 1               6674                             Luj  (7)              83.0
# 2               6675                        Dharwas  (11)              83.0
# 3               6676                      R.F.Kanyun  (8)              83.0
# 4               6677                        R.F.Urnu  (9)              83.0
# ...              ...                                  ...               ...
# 619495        645566  Butler Bay Forest Camp 4-III (FDCA)            5924.0
# 619496        645567   Butler Bay Forest Camp 4-IV (FDCA)            5924.0
# 619497        645568          Red Oil Palm (Nursery Camp)            5924.0
# 619498        645569   Butler Bay Forest Camp 4-II (FDCA)            5924.0
# 619499        645570    Butler Bay Forest Camp 4-I (FDCA)            5924.0
#
#         district_code
# 0                  23
# ...

# %%
df_villages = df_villages.drop_duplicates(subset=['village_code'])
df_villages = df_villages.drop_duplicates(
    subset=['village_name', 'subdistrict_code']
)

# %%
df_states.to_csv('processed_datasets/states.csv', index=False)
df_districts.to_csv('processed_datasets/districts.csv', index=False)
df_subdisticts.to_csv('processed_datasets/subdistricts.csv', index=False)
df_villages.to_csv('processed_datasets/villages.csv', index=False)

# %%
df_countries = pandas.DataFrame({
    'country_code': ['IN'],
    'country_name': ['India']
})
